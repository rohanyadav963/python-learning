# %% [markdown]
# ## Our first python program

# %%
print("hello world") #displaying message on the screen , 
#everything writen inside a duble quotes
# Out:
# hello world

# %% [markdown]
# ### Variable declaration and assigning a value

# %%
a = 23 # a is variable_name and 23 is a integer value 
b = 34 # b is variable_name and 34 is a integer value 
print(a+b) # sum calculate karta hai
# Out:
# 57

# %% [markdown]
# ### User se input lena iske liye input() use kiya jata hai

# %%
name = input("Enter your name:- " ) # default string input leta hai 
age = int(input("Enter your age:- ")) # string ko int me typcasting kiya hai
marks = float(input("Enter your marks:- ")) # float value input leta hai

print("Your name is ",name)
print("Your age is ",age)
print("Your marks is ",marks)
# Out:
# Your name is  Rohan
# Your age is  23
# Your marks is  76.66
